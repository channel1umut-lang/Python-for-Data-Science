# %% [markdown]
# <a href="https://colab.research.google.com/github/channel1umut-lang/Python-for-Data-Science/blob/main/0004_Intro_to_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
grades = {"Atil":50, "James":60, "Lans":30} #dictionary

# %%
pd.Series(grades) #series can help list them
# Out:
# Atil     50
# James    60
# Lans     30
# dtype: int64

# %%
names = "Atil","James","Lans"
grades = [50,60,30]

# %%
pd.Series(names)
# Out:
# 0     Atil
# 1    James
# 2     Lans
# dtype: object

# %%
pd.Series(grades)
# Out:
# 0    50
# 1    60
# 2    30
# dtype: int64

# %%
pd.Series(grades,names)
# Out:
# Atil     50
# James    60
# Lans     30
# dtype: int64

# %%
pd.Series(data=grades,index=names)
# Out:
# Atil     50
# James    60
# Lans     30
# dtype: int64

# %%
#with numpy

# %%
nump_array = np.array([10,20,30,40,50])

# %%
pd.Series(nump_array)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# arithmatic

# %%
contest_result = pd.Series(data = [10,5,100], index = ["Atil", "James", "Lars"])

# %%
contest_result2 = pd.Series(data = [20,50,10], index = ["Atil", "James", "Lars"])

# %%
contest_result
# Out:
# Atil      10
# James      5
# Lars     100
# dtype: int64

# %%
contest_result["Atil"]
# Out:
# np.int64(10)

# %%
contest_result2["James"]
# Out:
# np.int64(50)

# %%
final_result = contest_result + contest_result2

# %%
final_result # it understand that it need to sum datas itself
# Out:
# Atil      30
# James     55
# Lars     110
# dtype: int64

# %%
contest_result * contest_result2
# Out:
# Atil      200
# James     250
# Lars     1000
# dtype: int64

# %%
different_series = pd.Series([20,30,40,50],["a","b","c","d"])

# %%
different_series
# Out:
# a    20
# b    30
# c    40
# d    50
# dtype: int64

# %%
different_series2 = pd.Series([10,50,3,1],["a","c","f","g"])

# %%
different_series + different_series2 #sadece olan indexleri topldi the rest is NaN. NaN stands for “Not a Number,” which represents unrepresentable numeric values in Python
# Out:
# a    30.0
# b     NaN
# c    90.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64
